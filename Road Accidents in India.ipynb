# %% [markdown]
# <a href="https://colab.research.google.com/github/krish-spec/AI-Assignment/blob/main/Road%20Accidents%20in%20India.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x_cgpa = [2,3,4,5]
y_salary = [20000,30000,40000,50000]

# %%
plt.plot(x_cgpa,y_salary)
plt.xlabel('CGPA')
plt.ylabel('salary')
plt.title('SALARY and CGPA Distribution')
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
x_year = [2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]
y_RoadAccident = [439.26,460.92,479.22,484.07,486.38,499.63,497.63,490.38,486.48,489.4,501.42,480.65,464.91,467.04,449,366.14,412.43,461.31]

# %%
plt.plot(x_year,y_RoadAccident)
plt.xlabel('Year')
plt.ylabel('Number of Road Accident (in thousands)')
plt.title('Number of Road Accident in india from 2005 to 2022')
plt.show()
