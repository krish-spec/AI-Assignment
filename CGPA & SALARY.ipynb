# %% [markdown]
# <a href="https://colab.research.google.com/github/krish-spec/AI-Assignment/blob/main/CGPA%20%26%20SALARY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x_cgpa = [2,3,4,5]
y_salary = [20000,30000,40000,50000]

# %%
plt.plot(x_cgpa,y_salary)
plt.xlabel('CGPA')
plt.ylabel('salary')
plt.title('SALARY and CGPA Distribution')
plt.show()
